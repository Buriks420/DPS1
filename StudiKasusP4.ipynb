# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("{:^40}".format ("Pendaftaran Mahasiswa Baru"))
NIS = input ("Masukan NIS : ")
Nama = input ("Masukan Nama : ")
Jurusan = input ("Masukan Jurusan :")

if Jurusan == "SI" or Jurusan == "si":
    kodeprodi = "Sistem Informasi"
    Harga = 2400000

if Jurusan == "SIA" or Jurusan == 'sia':
    kodeprodi = "Sistem Informasi Akuntansi"
    Harga = 2000000
print("==================================")
print("Nomer Induk Siswa : ", NIS)
print("Nama              : ", Nama)
print("Kode Jurusan      : ", Jurusan)
print("Nama Prodi        : ", kodeprodi)
print("Harga             : ", Harga)
print("==================================")
# Out:
#        Pendaftaran Mahasiswa Baru
# ...
# Nomer Induk Siswa :  12345678
# Nama              :  ███████████
# Kode Jurusan      :  sia
# Nama Prodi        :  Sistem Informasi Akuntansi
# Harga             :  2000000
# ...
