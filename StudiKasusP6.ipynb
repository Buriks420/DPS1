# %% [markdown]
# ![image.png](attachment:image.png)

# %%
listarray = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9],
    [0]
]

print("Baris Pertama, Kolom Pertama Adalah :" ,listarray[0][0])
print("Baris Pertama, Kolom Kedua Adalah :" ,listarray[0][1])
print("Baris Pertama, Kolom Ketiga Adalah :" ,listarray[0][2])
print("Baris Ketiga, Kolom Ketiga Adalah :" ,listarray[2][2])
print("Baris Ke empat, Kolom Pertama Adalah :" ,listarray[3][0])
# Out:
# Baris Pertama, Kolom Pertama Adalah : 1
# Baris Pertama, Kolom Kedua Adalah : 2
# Baris Pertama, Kolom Ketiga Adalah : 3
# Baris Ketiga, Kolom Ketiga Adalah : 9
# Baris Ke empat, Kolom Pertama Adalah : 0
